# %% [markdown]
# ### Phyton Data Types

# %% [markdown]
# a few data types:
# - Text type : string (str)
# - Numeric Types : integer (int), float (float), complex.
# - Sequence types : list, tuple, range
# -Mapping Type : dict
# - Set Types : set, frozenset
# -Boolean Type : bool
# - Binary Types : bytes, bytearray, memoryview

# %% [markdown]
# ### Arithmetic Operators

# %%
a = 4
b = 3

print (a + b) #penjumlahan
print (a - b) #pengurangan
print(a * b) #perkalian
print(a / b) #pembagian
print (a % b) #sisa hasil bagi
print (a ** b) #pangkat

# %% [markdown]
# ### String Manipulation

# %%
s = 'moon'
f = 'light'

# + and * Operators
print(s + f)
print(s * 4)

#Case Conversion
print(s.capitalize())
print(s.capitalize())
print(s.lower())
print(s.swapcase)

# %% [markdown]
# ### List

# %% [markdown]
# some of list's characteristics are :
# - defined by [ ]
# - Ordered (the order matters)
# - Can contain anything
# - Can be accessed by index
# - Can be nested to arbitrary depth
# - Mutable
# - Dynamic

# %%
list1 = ['moon', 'euphoria', 'people', 'd-2']
print(list1)

# %% [markdown]
# modifying list value

# %% [markdown]
# a single value in a list can be replaced by indexing and simple assignment, i,e:

# %%
list1[2] = 'dyonisus' #replace second index (generally known as third place)
list1[-1] = 'fire' #first from the back is replaced.
print(list1)

# %% [markdown]
# ### Tuples

# %% [markdown]
# defined by ( ) instead of [ ]. Immutable.

# %%
tuples1 = ('black swan', 'coffee', 'dna', 'agustd')
print(tuples1)
print(tuples1[0])
print(tuples1[-1])

# %% [markdown]
# packing and unpacking

# %%
(s1,s2,s3,s4) = ('black swan', 'coffee', 'dna', 'agustd')
print(s1)

# %% [markdown]
# ### Dictionary

# %% [markdown]
# - mutable.
# - dynamic. can grow and shrink as needed.
# - can be nested. can contain dictionary in a dictionary. can contain list in a dictionary. vv with list.
# - accessed by keys

# %%
BTS_Songs = {
    'SUGA' : 'Agustd',
    'Jimin' : 'Filter',
    'Jin' : 'Epiphany',
}
print(BTS_Songs['Jimin'])

# %%
#Adding an Entry to an existing dictionary
BTS_Songs['RM'] = 'Bicycle'
BTS_Songs

# %% [markdown]
# #### Building a Dictionary Incrementally

# %% [markdown]
# - start by creating an empty dictionary, specified by empty curly braces { }.
# - then add new keys and values one at a time.

# %%
bts_leader = { }
bts_leader['name'] = 'Kim Nam Joon'
bts_leader['stage name'] = 'RM'
bts_leader['age'] = 27
bts_leader['nationality'] = 'South Korean'
bts_leader['spouse'] = 'Single'
bts_leader['agency'] = 'HYBE'
bts_leader['pet'] = 'Rapmon (Dog)'
print(bts_leader)
print(bts_leader['stage name'])
print(bts_leader['stage name'][1])

# %% [markdown]
# ### Conditional

# %% [markdown]
# - Equals : a == b
# - Not equals : a != b
# - Less than: a < b
# - Less than or equal to : a <= b
# - Greater than : a > b
# - Greater than or equal to : a >= b
# These conditions can be used in several ways, most commonly in **'if statements'** and **loops**

# %% [markdown]
# ### If Statement

# %% [markdown]
# ##### syntax :
# ##### - if <expression>:
# ##### -   <statement>
#
# - <expression> : is an expression evaluated in boolead context.
# - <statement>   : is a valid python statement, which must be indented.
#
# - in if statement, the computer first evaluates whether the <statement> is considered True or False. if it is **true** then the <statement> is executed. if it is **false** then the <statement> is **Not** executed.

# %% [markdown]
# ### Break and Continue Statements

# %%
#example of a break statement :

n = 5
while n > 0 :
    n -= 1
    if n == 2 :
        break #break statement
    print(n)
print('Loop Ended.')

# %%
# break the loop as soon as it sees 'e' or 'd'
i = 0 #define the variable used as a looping thingy
a = 'hopeworld'

while i < len(a):
    if a[i] == 'e' or a[i] == 'd': #we set the conditions 
        i += 1 #set how the loop should operate
        break

    print('Current Letter : ', a[i]) #to print what letter is currently looping
    i += 1

# %%
# print all letters except 'e' or 'd' (continue statement. di lompatin)
i = 0 #define the variable used as a looping thingy
a = 'hopeworld'

while i < len(a):
    if a[i] == 'e' or a[i] == 'd': #set the conditions
        i += 1 #set how the loop should operate
        continue

    print('Current Letter : ', a[i]) #to print what letter is currently looping
    i += 1

# %% [markdown]
# ### For-Else and While-Else

# %% [markdown]
# - the **else clause** will **NOT** be executed if the loop gets terminated by **a break statement**.
# - if a loop does not hit a break statement, then the **else clause** will be executed **once** after the loop has completed all its iterations (after the loop has completed **normally**, then the else statement will be executed)

# %% [markdown]
# the example below is using the for else with a break statement to do a search job

# %%
my_treasure_box = ["a", "b", "Diamond", "c"] #define the list used

def search(search_item):
    for item in my_treasure_box:
        if(item==search_item):
            print(f"{search_item} Found!")
            break
    else:
        print(f"No {search_item} found.")


search("Diamond")
search("Gold")

# %% [markdown]
# the example below is using break statement and loop's else clause to check limits

# %%
#define all variables
lower_limit = 5
upper_limit = 10

def validate_limits(input_data):
    for i in input_data:
        if(i <= lower_limit or i >= upper_limit):
            print(f"{input_data}: At least one value breaches limits")
            break
    else: #no break
        print(f"{input_data}: Values Validated.")


validate_limits([1,6,11])
validate_limits([6,7,8])

# %% [markdown]
# ### Else statement used with loops

# %% [markdown]
# - if the **else statement** is used a **for loop** , the else statement **is executed** when **the loop has exhausted iterating the list**.
# - if the **else statement** is used with a **while loop**, the else statement **is executed** when **the condition becomes false**.

# %%
#this example illustrates the combination of an else statement with a for statement
#searches for a prime numbers from 10 through 20
for num in range(10,20): #to iterate between 10 to 20
    for i in range(2, num): #to iterate on the factors of the number
        if num%i == 0: #to determine the first factor
            j=num/i #to calculate the second factor
            print ('%d equals %d * %d' % (num,i,j))
            break #to move to the next number, the #first FOR
else: #else part of the loop
    print (f"{num}, is a prime number")

# %% [markdown]
# ### Nested Loops ( A loop inside a loop)

# %% [markdown]
# - When we have to manage nested loops, we can easily break from an inner loop and get the line of execution to the outer loop using a break statement.
# - if we need to check whether the inner loop completed executing all its iterations normally without hitting a break statement, we could use the loop's else clause.
# - **REMEMBER**, in python we cannot break multiple nested loops using a single break statement. One break statement can only break the one loop which contains it.

# %%
#define the variables and establish the dictionary used
teams_data = [
    {"team_name":"A", "team_scores": [5, 3, 2]},
    {"team_name":"B", "team_scores": [4,2, None]}
]

for team in teams_data:
    total_score = 0 
    name = team["team_name"]

    for score in team["team_scores"]:
        if score == None:
            print(f"Team {name} Score : Incomplete Data")
            break

    else:
        print(f"Team {name} Score: {total_score}")

# %% [markdown]
# ### One-Line while Loops

# %% [markdown]
# as with an **if statement**, a while loop **can** be specified on **one line**. If there are multiple statements in the block that makes up the loop body, they can be separated by semicolons (;).

# %% [markdown]
# The example below will print 4 to 0 numbers:

# %%
a = 5
while a > 0: a = a - 1 ; print(a)

# %% [markdown]
# Limitations;
# - if we do not define the end of the loop, it will run infinite iteration.
# - use exit before running it.
#
# i.e :

# %%
while True: print('Hello') ; exit(3);
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...

# %% [markdown]
# ##### Nested Compound Statements while Loop Single Line

# %% [markdown]
# when using a **compound statement** in Python (statements that need a suite, an indented block), and that block contains *only* simple statements, we can remove the newline, and separate the simple statements with semicolons.

# %% [markdown]
# ***HOWEVER!!!!***
# 1. this **does not** support compound statements
# 2. only works in simple statements *after* the compound statement.

# %%
a = range(0, 10)

if a == 2 : print("something")
 #this works

a
# Out:
# range(0, 10)

# %%
a = range(10)

while a == 2:if a % 2 != 0 : print("something")

#this does not work
# Out:
#   Input In [15]
#     while a == 2:if a % 2 != 0 : print("something")
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Range () Function

# %% [markdown]
# - the range () function returns a sequence of numbers.
# - it starts from 0 by default, and increments by 1 (default), and stops before a specified number.
# - syntax ; range(start, stop, step)

# %%
x = range(5)

for n in x:
    print(n)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# this example creates a sequence of numbers from 3 to 5, and print each item in the sequence.

# %%
x = range(3, 6) #we do not need to specify the steps since it is by default ( 1 step). remember that it ends **before** the number we want (end = stop - 1)
for n in x:
    print(n)
# Out:
# 3
# 4
# 5

# %% [markdown]
# ### Altering for Loop Behavior

# %% [markdown]
# to alter a for loop behavior, we can use either
# 1. break
# 2. continue
#
#
# - break terminates the loop completely and proceeds to the first statement following in the loop.
# - continue terminates the current iteration and proceeds to the next (it skips a certain step)

# %%
for i in ["dyonisus", "dna", "euphoria","epiphany", "7", "agustd"]:
    if 'e' in i:
        break
    print(i)
# Out:
# dyonisus
# dna

# %%
for i in  ["dyonisus", "dna", "euphoria","epiphany", "7", "agustd"]:
    if 'e' in i:
        continue
    print(i)
# Out:
# dyonisus
# dna
# 7
# agustd

# %% [markdown]
# ### Function

# %% [markdown]
# - function is a block of code which only runs when it is called.
# - we can pass data, known as *parameters*, into a function.
# - a function can return data as a result

# %% [markdown]
# In python, a function is defined using the def keyword

# %% [markdown]
# below we define the function:

# %%
def function1():
    print("Hi! I'm a function")

# %% [markdown]
# then we call it:

# %%
function1()
# Out:
# Hi! I'm a function

# %% [markdown]
# ##### Arguments
# - Information can be passed into functions as arguments.
# - arguments are specified after the function name, inside the parentheses (). we can add as many arguments as we want, just separate them with a comma.

# %% [markdown]
# below is a function with one argument (fname). When the function is called, we pass along a first name, which is used inside the function to print the full name :

# %%
def function2 (fname):
    print(fname + "Refsnes")

# %%
function2("Jack")
# Out:
# JackRefsnes
