# %% [markdown]
# ## Data Analysis

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# 1. how to import data:
# pd.read_csv('directory filenya')

# %%
df = pd.read_csv("../Datasets/StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# cara kedua bisa juga langsung stream data dari internet

# %%
ds = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
ds
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
ds.shape
# Out:
# (126314, 23)

# %% [markdown]
# lihat sampel data dulu

# %%
ds.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %% [markdown]
# 1. yang diatas tadi nggak semua kolomnya muncul karena banyak banget
# 2. ini caranya biar muncul semua kolomnya:

# %%
pd.set_option('display.max_columns', None)

# %%
ds.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %% [markdown]
# gunanya parenthesis di (var).head() itu buat kontrol mau berapa baris.
# defaultnya top 5

# %%
ds.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %% [markdown]
# (var).head top 5 (default) (var).tail bottom 5 (default)

# %%
ds.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.4149  1704.3949
# 126310         102            1     GSW   Warriors  104  1809.9791  1813.6349
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %% [markdown]
# cari tau gambaran besar dari datanya (nama kolom, berapa banyak data yang terisi (non=null count)):

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# 1. sebaiknya tipe data yang bisa diganti jadi selain object, diganti
# 2. karena ada beberapa operasi di Pandas yang gabisa dioperasikan kalo di object
# 3. dan karena objects itu besar. mengganti objects berarti mengurangi penggunaan memori RAM

# %% [markdown]
# setelah ini, describe data yang berupa integer:

# %%
ds.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %% [markdown]
# untuk milih nampilkan salah satu kolom data aja :

# %%
ds['team_id']
# Out:
# 0         TRH
# 1         NYK
# 2         CHS
# 3         NYK
# 4         DTF
#          ...
# 126309    CLE
# 126310    GSW
# 126311    CLE
# 126312    CLE
# 126313    GSW
# Name: team_id, Length: 126314, dtype: object

# %% [markdown]
# value counts buat nunjukkin seberapa sering suatu value itu muncul (disini dalam salah satu kolom spesifik yang dipanggil juga)

# %%
ds['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
ds['fran_id'].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %% [markdown]
# buat nyari suatu data spesifik bisa pakai loc

# %%
ds.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
ds.loc[ds['team_id'] == 'TRH'].head(2)
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0           1  194611010TRH   NBA        0     1947  11/1/1946           1
# 10          6  194611030CLR   NBA        1     1947  11/3/1946           2
#
#     is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0             0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 10            0     TRH  Huskies   60  1293.2767  1286.1534  39.548164    CLR
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 0    Knicks       68     1300.0  1306.7233             H           L
# 10   Rebels       71     1300.0  1307.1233             A           L
#
#     forecast notes
# 0   0.640065   NaN
# 10  0.351068   NaN

# %%
ds.loc[ds['fran_id'] == 'Lakers']
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1136          569  194811040BLB   NBA        1     1949   11/4/1948
# 1152          577  194811060WSC   NBA        1     1949   11/6/1948
# 1159          580  194811090BOS   NBA        1     1949   11/9/1948
# 1170          586  194811110NYK   NBA        1     1949  11/11/1948
# 1183          592  194811130PRO   NBA        1     1949  11/13/1948
# ...           ...           ...   ...      ...      ...         ...
# 126016      63009  201504080DEN   NBA        1     2015    4/8/2015
# 126052      63027  201504100LAL   NBA        0     2015   4/10/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
# 126115      63058  201504130SAC   NBA        1     2015   4/13/2015
# 126137      63069  201504150LAL   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# ...

# %% [markdown]
# buat value count team_id di fran_id tertentu

# %%
ds.loc[ds['fran_id'] == 'Lakers', 'team_id']
# Out:
# 1136      MNL
# 1152      MNL
# 1159      MNL
# 1170      MNL
# 1183      MNL
#          ...
# 126016    LAL
# 126052    LAL
# 126086    LAL
# 126115    LAL
# 126137    LAL
# Name: team_id, Length: 6024, dtype: object

# %%
ds.loc[ds['fran_id'] == 'Lakers', 'team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %% [markdown]
# Misal kita mau menjumlahkan semua poin pada suatu tim :

# %%
ds.loc[ds['team_id'] == 'TRH'].head(2)
# Out:
#     gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0           1  194611010TRH   NBA        0     1947  11/1/1946           1
# 10          6  194611030CLR   NBA        1     1947  11/3/1946           2
#
#     is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0             0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 10            0     TRH  Huskies   60  1293.2767  1286.1534  39.548164    CLR
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 0    Knicks       68     1300.0  1306.7233             H           L
# 10   Rebels       71     1300.0  1307.1233             A           L
#
#     forecast notes
# 0   0.640065   NaN
# 10  0.351068   NaN

# %%
ds.loc[ds['team_id'] == 'TRH', 'pts'].sum()
# Out:
# 3995

# %%
ds.loc[ds['team_id'] == 'TRH', 'pts'].mean()
# Out:
# 66.58333333333333

# %% [markdown]
# buat slicing:

# %%
ds.loc[5000:6000, 'pts']
# Out:
# 5000     85
# 5001     90
# 5002     79
# 5003     94
# 5004     98
#        ...
# 5996     94
# 5997     97
# 5998     84
# 5999     91
# 6000    107
# Name: pts, Length: 1001, dtype: int64

# %%
ds.loc[5000:6000, ['pts', 'team_id', 'opp_pts', 'opp_id']]
# Out:
#       pts team_id  opp_pts opp_id
# 5000   85     PHW       90    NYK
# 5001   90     NYK       85    PHW
# 5002   79     BLB       94    SYR
# 5003   94     SYR       79    BLB
# 5004   98     SYR       77    BLB
# ...   ...     ...      ...    ...
# 5996   94     SYR       97    MNL
# 5997   97     MNL       94    SYR
# 5998   84     MLH       91    NYK
# 5999   91     NYK       84    MLH
# 6000  107     BOS       84    SYR
#
# [1001 rows x 4 columns]

# %% [markdown]
# ### Querying Data

# %% [markdown]
# ini pokoknya buat data yang spesifik. gabisa pakai loc

# %%
ds.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
ds[
    ds['year_id'] > 1950
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 3076         1539  195010310ROC   NBA        1     1951  10/31/1950
# 3077         1539  195010310ROC   NBA        0     1951  10/31/1950
# 3078         1540  195011010BLB   NBA        1     1951   11/1/1950
# 3079         1540  195011010BLB   NBA        0     1951   11/1/1950
# 3080         1541  195011010FTW   NBA        1     1951   11/1/1950
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# ...

# %% [markdown]
# kalo kondisinya lebih dari 1, tiap kondisinya harus dibungkus dengan ( )

# %%
ds[
    (ds['year_id'] > 1950) &
    (ds['fran_id'] == 'Knicks') &
    (ds['pts'] > 150)
    ]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 9274         4638  195912110NYK   NBA        0     1960  12/11/1959
# 20785       10393  197002130PHI   NBA        1     1970   2/13/1970
# 103990      51996  200612270NYK   NBA        0     2007  12/27/2006
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# 9274            23            0     NYK  Knicks  152  1455.3502  1481.0966
# 20785           63            0     NYK  Knicks  151  1646.8032  1673.8684
# 103990          31            0     NYK  Knicks  151  1391.4535  1403.1624
#
#         win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 9274    37.764519    SYR   Sixers      121  1594.9003  1569.1539
# 20785   61.501518    PHI   Sixers      106  1523.8624  1496.7972
# 103990  31.006033    DET  Pistons      145  1621.2067  1609.4978
#
#        game_location game_result  forecast notes
# 9274               H           W  0.443327   NaN
# ...

# %%
ds[
    (ds['team_id'] == 'BLB' ) &
    (ds['pts'] > 100) &
    (ds['opp_pts'] > 100) &
    (ds['year_id'] == 1953)
]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
#
#       is_playoffs team_id    fran_id  pts      elo_i      elo_n  win_equiv  \
# 4890            0     BLB  Baltimore  126  1328.6687  1356.6470  25.797792
# 4909            0     BLB  Baltimore  104  1349.8323  1346.3594  24.876236
# 5208            0     BLB  Baltimore  107  1284.5239  1282.2396  19.579676
#
#      opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 4890    BOS  Celtics      105  1591.1434  1563.1652             H           W
# 4909    MNL   Lakers      112  1665.4396  1668.9125             H           L
# 5208    NYK   Knicks      113  1649.1516  1651.4359             H           L
#
#       forecast         notes
# ...

# %% [markdown]
# cara kedua untuk query, yaitu pakai keyword **QUERY**

# %%
ds.query( "team_id == 'BLB' & pts > 100 & opp_pts > 100 & year_id == 1953")
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
#
#       is_playoffs team_id    fran_id  pts      elo_i      elo_n  win_equiv  \
# 4890            0     BLB  Baltimore  126  1328.6687  1356.6470  25.797792
# 4909            0     BLB  Baltimore  104  1349.8323  1346.3594  24.876236
# 5208            0     BLB  Baltimore  107  1284.5239  1282.2396  19.579676
#
#      opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 4890    BOS  Celtics      105  1591.1434  1563.1652             H           W
# 4909    MNL   Lakers      112  1665.4396  1668.9125             H           L
# 5208    NYK   Knicks      113  1649.1516  1651.4359             H           L
#
#       forecast         notes
# ...

# %% [markdown]
# ### Grouping and Aggregating Data

# %% [markdown]
# *self-explanatory* buat ngegroup data

# %%
ds.groupby('fran_id')['pts'].sum().head(10)
# Out:
# fran_id
# Baltimore     37219
# Bombers       17793
# Bucks        418326
# Bulls        437269
# Capitols      22387
# Cavaliers    380416
# Celtics      626484
# Clippers     380523
# Colonels      94435
# Condors       49642
# Name: pts, dtype: int64

# %%
ds.groupby('fran_id')['pts'].max().head(10)
# Out:
# fran_id
# Baltimore    126
# Bombers      109
# Bucks        166
# Bulls        156
# Capitols     118
# Cavaliers    154
# Celtics      173
# Clippers     152
# Colonels     157
# Condors      156
# Name: pts, dtype: int64

# %%
ds.groupby('team_id')['pts'].max().head(10)
# Out:
# team_id
# ANA    147
# AND    123
# ATL    155
# BAL    156
# BLB    126
# BOS    173
# BRK    134
# BUF    145
# CAP    126
# CAR    156
# Name: pts, dtype: int64

# %%
ds[
    (ds['year_id'] > 2010) &
    (ds['fran_id'] == 'Knicks')
].groupby('year_id')['pts'].sum()
# Out:
# year_id
# 2011    9097
# 2012    6872
# 2013    9259
# 2014    8084
# 2015    7535
# Name: pts, dtype: int64

# %%
ds[
    (ds['year_id'] > 2010) &
    (ds['fran_id'] == 'Knicks')
].groupby(['year_id', 'game_location'])['pts'].sum()
# Out:
# year_id  game_location
# 2011     A                4480
#          H                4617
# 2012     A                3420
#          H                3452
# 2013     A                4404
#          H                4753
#          N                 102
# 2014     A                3986
#          H                4098
# 2015     A                3706
#          H                3750
#          N                  79
# Name: pts, dtype: int64

# %%
ds[
    (ds['year_id'] > 2010) &
    (ds['fran_id'] == 'Knicks')
].groupby(['year_id', 'team_id', 'game_location'])['pts'].sum()
# Out:
# year_id  team_id  game_location
# 2011     NYK      A                4480
#                   H                4617
# 2012     NYK      A                3420
#                   H                3452
# 2013     NYK      A                4404
#                   H                4753
#                   N                 102
# 2014     NYK      A                3986
#                   H                4098
# 2015     NYK      A                3706
#                   H                3750
#                   N                  79
# Name: pts, dtype: int64

# %% [markdown]
# ### Manipulating Columns

# %%
ds
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %% [markdown]
# - kalo mau ada operating yang majorly affecting the data, better to copy the data first dulu.
# - biar nggak berpengaruh ke data asli.
# - **BACKUP**

# %%
ds_copy = ds.copy()

# %%
ds_copy.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %% [markdown]
# - menghapus kolom pakai .drop
# - karena **kolom** harus pakai axis = 1

# %% [markdown]
# buat liat preview dari hapusan:

# %%
ds_copy.drop('elo_i', axis= 1)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_n  win_equiv  \
# 0                1            0     TRH    Huskies   66  1293.2767  40.294830
# ...

# %% [markdown]
# -kalo mau permanently hapus, 2 cara:
# 1. masukin ke variabel baru : ds_copy_noeloi = ds_copy.drop('elo_i', axis= 1)
# 2. bisa juga tanpa backupan : ds_copy.drop('elo_i', axis= 1, inplace=True)

# %%
ds_copy_noeloi = ds_copy.drop('elo_i', axis= 1)

# %%
ds_copy_noeloi
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_n  win_equiv  \
# 0                1            0     TRH    Huskies   66  1293.2767  40.294830
# ...

# %% [markdown]
# masih ada file yang ada elo_i nya

# %%
ds_copy
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %% [markdown]
# elo_i permanently gone:

# %%
ds_copy.drop('elo_i', axis= 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [107], in <module>
# ----> 1 ds_copy.drop('elo_i', axis= 1, inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4906, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4774 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4775 def drop(
#    4776     self,
#    (...)
# ...

# %%
ds_copy
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_n  win_equiv  \
# 0                1            0     TRH    Huskies   66  1293.2767  40.294830
# ...

# %% [markdown]
# ### Rename

# %% [markdown]
# ini preview btw

# %%
ds_copy.rename(columns= {'game_location':'location', 'game_results':'results'})
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_n  win_equiv  \
# 0                1            0     TRH    Huskies   66  1293.2767  40.294830
# ...

# %% [markdown]
# permanently ganti, sama kayak yang tadi:
# 1. masukin ke index baru
# 2. permanently

# %%
ds_copyR = ds_copy.rename(columns= {'game_location':'location', 'game_results':'results'})

# %%
ds_copyR
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_n  win_equiv  \
# 0                1            0     TRH    Huskies   66  1293.2767  40.294830
# ...

# %%
ds_copy.rename(columns= {'game_location':'location', 'game_results':'results'}, inplace= True)

# %%
ds_copy.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_n  win_equiv opp_id opp_fran  \
# 0            0     TRH  Huskies   66  1293.2767   40.29483    NYK   Knicks
# 1            0     NYK   Knicks   68  1306.7233   41.70517    TRH  Huskies
#
#    opp_pts  opp_elo_i  opp_elo_n location game_result  forecast notes
# 0       68     1300.0  1306.7233        H           L  0.640065   NaN
# 1       66     1300.0  1293.2767        A           W  0.359935   NaN

# %%
ds_copy.rename(columns= {'game_result':'results'}, inplace= True)

# %%
ds_copy.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_n  win_equiv opp_id opp_fran  \
# 0            0     TRH  Huskies   66  1293.2767   40.29483    NYK   Knicks
# 1            0     NYK   Knicks   68  1306.7233   41.70517    TRH  Huskies
#
#    opp_pts  opp_elo_i  opp_elo_n location results  forecast notes
# 0       68     1300.0  1306.7233        H       L  0.640065   NaN
# 1       66     1300.0  1293.2767        A       W  0.359935   NaN
